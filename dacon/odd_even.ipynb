# %% [markdown]
# ## 문제
#
# ### 파이썬의 if else 제어문을 활용하여 number의 홀짝 여부를 출력하시오.
#
#
# 입력 : 7
#
# 출력 : 홀수입니다.

# %%
number = int(input('입력 : '))

if number % 2 == 0:
    print('출력 : 짝수입니다.')

else:
    print('출력 : 홀수입니다.')
# Out:
# 입력 : 7
# 출력 : 홀수입니다.
