# %% [markdown]
# ## Q) 문자열 포매팅에서 'year', 'month', 'day' 변수를 이용하여, 다음 문자열을 출력해 보세요.
#
#
# ### 문제
#
# year = 2021<br>
# month = 6<br>
# day = 3<br>
# 문자열 : '오늘은 2021년 6월 3일 입니다.'

# %%
year = 2021
month = 6
day = 3

'오늘은 %d년 %d월 %d일 입니다.'%(year, month, day)
# Out:
# '오늘은 2021년 6월 3일 입니다.'
