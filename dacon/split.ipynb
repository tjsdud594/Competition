# %% [markdown]
# ## Q) 문자열 함수 중 split 함수를 이용하여 문자열 str1을 str_list로 변환해 보세요.
#
# ### 문제
#
# str1 = ' a to b to c to d '<br>
# str_list = ['a', 'b', 'c', 'd']

# %%
str1 = 'a to b to c to d'
str1.split('to')
# Out:
# ['a ', ' b ', ' c ', ' d']
