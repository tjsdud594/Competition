# %% [markdown]
# ## Q) 문자열 자료형 인덱싱의 결과로 옳지 않은 것은?
#
# str = 'dacon'<br>
#
# 1. str[0] = d<br>
# 2. str[-1] = n<br>
# 3. str[-5] = d<br>
# 4. str[4] = o<br>

# %%
# 정답 : 4
str = 'dacon'

str[4]
# Out:
# 'n'
