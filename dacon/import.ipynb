# %% [markdown]
# # 실습
# ---
# 아래 pandas 라이브러리를 pd 이름으로 불러오는 코드를 작성해보세요.

# %%
import [라이브러리] as [사용할 이름]

# %%
import pandas as pd

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 정답
# ---
# `숨겨진 셀 1개` 를 누르시면 정답을 볼 수 있습니다.

# %%
import pandas as pd
