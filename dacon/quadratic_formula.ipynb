# %% [markdown]
# ## Q) 파이썬에서 근의 공식을 작성 해 보세요.
#
# 근의 공식<br>
# ax^2+bx+c=0

# %%
a = 1
b = -4
c = 1

x1 = (-b+(b**2-4*a*c)**(0.5))/2*a
x2 = (-b-(b**2-4*a*c)**(0.5))/2*a

print(x1)
print(x2)
# Out:
# 3.732050807568877
# 0.2679491924311228
