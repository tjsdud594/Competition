# %% [markdown]
# ## Q) 다음과 같이 문자열을 출력하는 파이썬 코드가 아닌것은 무엇인가요? (공백 포함)
#
# ### 실행결과
#
# 함께해요 오늘의 파이썬

# %%
print('함께해요 오늘의 파이썬')

print('함께해요', '오늘의', '파이썬')

print('함께해요'+'오늘의'+'파이썬')

str1 = '함께해요'
str2 = '오늘의 파이썬'
print(str1, str2)
# Out:
# 함께해요 오늘의 파이썬
# 함께해요 오늘의 파이썬
# 함께해요오늘의파이썬
# 함께해요 오늘의 파이썬

# %% [markdown]
# 정답 : 세번쨰
