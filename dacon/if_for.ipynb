# %% [markdown]
# ## 문제
#
#
# ### 반복문과 조건문만 활용하여 1~10까지 숫자 중 짝수만 담긴 리스트 a를 출력하시오.

# %%
a = []

for i in range(1,11):
    if i % 2 == 0:
        a.append(i)
    print(a)
# Out:
# []
# [2]
# [2]
# [2, 4]
# [2, 4]
# [2, 4, 6]
# [2, 4, 6]
# [2, 4, 6, 8]
# [2, 4, 6, 8]
# [2, 4, 6, 8, 10]
