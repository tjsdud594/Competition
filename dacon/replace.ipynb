# %% [markdown]
# ## Q) 문자열 함수 중 replace 함수를 이용하여 str1 -> str2로 변환해 보세요.
#
#
# ### 문제
#
# str1 = 'Only you can stop yourself'<br>
# str2 = 'Only you can change yourself'

# %%
str = 'Only you can stop yourself'

str.replace('stop', 'change')
# Out:
# 'Only you can change yourself'
