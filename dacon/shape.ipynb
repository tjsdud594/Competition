# %% [markdown]
# # [↩️ 리스트로 돌아가기](https://dacon.io/competitions/open/235698/overview/description)

# %% [markdown]
# # 셀을 실행할 때 팝업이 뜨면 `무시하고 계속하기` 를 눌러주세요

# %% [markdown]
# ## 1️⃣ 데이터 다운로드
# ---
# 아래 셀을 실행시켜 데이터를 colab에 불러옵니다.
# 셀 실행은 <br>Windows: `Ctrl` + `Enter`<br>
# Mac: `Shift` + `Enter` <br>
# 를 이용해 실행 시킬 수 있습니다.

# %%
# 데이터 다운로드 링크로 데이터를 코랩에 불러옵니다.

# !wget 'https://bit.ly/3gLj0Q6'

import zipfile
with zipfile.ZipFile('3gLj0Q6', 'r') as existing_zip:
    existing_zip.extractall('data')
# Out:
# --2021-06-24 14:01:12--  https://bit.ly/3gLj0Q6
# Resolving bit.ly (bit.ly)... 67.199.248.10, 67.199.248.11
# Connecting to bit.ly (bit.ly)|67.199.248.10|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://drive.google.com/uc?export=download&id=1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E [following]
# --2021-06-24 14:01:12--  https://drive.google.com/uc?export=download&id=1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E
# Resolving drive.google.com (drive.google.com)... 172.217.2.110, 2607:f8b0:4004:80a::200e
# Connecting to drive.google.com (drive.google.com)|172.217.2.110|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/9tc4rmqp9tg43p1h45sbpgri4s1111ab/1624543200000/17946651057176172524/*/1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2021-06-24 14:01:13--  https://doc-0c-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/9tc4rmqp9tg43p1h45sbpgri4s1111ab/1624543200000/17946651057176172524/*/1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E?e=download
# Resolving doc-0c-10-docs.googleusercontent.com (doc-0c-10-docs.googleusercontent.com)... 172.217.2.97, 2607:f8b0:4004:80a::2001
# Connecting to doc-0c-10-docs.googleusercontent.com (doc-0c-10-docs.googleusercontent.com)|172.217.2.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39208 (38K) [application/zip]
# Saving to: ‘3gLj0Q6’
#
# 3gLj0Q6             100%[===================>]  38.29K  --.-KB/s    in 0.007s
#
# 2021-06-24 14:01:13 (5.29 MB/s) - ‘3gLj0Q6’ saved [39208/39208]

# %% [markdown]
# ## 2️⃣ 데이터 불러오기
# ---
# 아래 셀을 실행시켜 csv 파일을 DataFrame 객체로 불러옵니다.

# %%
import pandas as pd

#데이터 불러오기
train = pd.read_csv('data/train.csv') 
test = pd.read_csv('data/test.csv')

# %% [markdown]
# ## 실습
# ---
# shape 를 이용해 train 과 test 의 행과 열의 갯수를 파악하는 코드를 아래 셀에서 실습해보세요

# %%
train.shape
# Out:
# (1459, 11)

# %%
test.shape
# Out:
# (715, 10)

# %% [markdown]
# ## 정답
# ---
# 스스로 실습 코드를 작성 한 후 정답 코드를 확인해 보세요

# %%
train.shape
# Out:
# (1463, 11)

# %%
test.shape
# Out:
# (717, 10)

# %% [markdown]
# # [↩️ 리스트로 돌아가기](https://dacon.io/competitions/open/235698/overview/description)
