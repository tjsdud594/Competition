# %% [markdown]
# ## Q) 파이썬에서 소수점 이하 3자리까지 출력하는 방법이 아닌 것은?
#
# ### 실행결과
#
# - num=1.23456<br>
# num : 1.235

# %%
num = 1.23456

print("num :","%.3f"%num)
print("num :",round(num,3))
print("num :","{:.3f}".format(num))
print("num :","{.3f}".format(num))
# Out:
# num : 1.235
# num : 1.235
# num : 1.235
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-b6b2e51ff257> in <module>
#       4 print("num :",round(num,3))
#       5 print("num :","{:.3f}".format(num))
# ----> 6 print("num :","{.3f}".format(num))
#
# AttributeError: 'float' object has no attribute '3f'

# %% [markdown]
# 4번이 오류
